# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Public\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("D:\Data Analysis\Assignments\census-income_ (1).csv")

# %%
df.sample(5)
# Out:
#        age   workclass   fnlwgt      education   education-num  \
# 20936   39   Local-gov   214284      Bachelors              13
# 22075   19           ?    61855        HS-grad               9
# 19213   23     Private   165474   Some-college              10
# 14278   38     Private   146178        HS-grad               9
# 13354   19     Private   212468   Some-college              10
#
#        marital-status       occupation     relationship                 race  \
# 20936         Widowed   Prof-specialty        Unmarried   Asian-Pac-Islander
# 22075   Never-married                ?   Other-relative                White
# 19213   Never-married     Craft-repair    Not-in-family                White
# 14278   Never-married     Craft-repair        Unmarried                Black
# 13354   Never-married    Other-service        Own-child                White
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country  \
# 20936   Female              0              0               10           Japan
# 22075   Female              0              0               30   United-States
# 19213     Male              0              0               40   United-States
# 14278   Female              0              0               40   United-States
# 13354   Female              0              0               15   United-States
#
#       Unnamed: 14
# 20936       <=50K
# 22075       <=50K
# 19213       <=50K
# 14278       <=50K
# 13354       <=50K

# %%
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country Unnamed: 14
# 0           2174              0               40   United-States       <=50K
# 1              0              0               13   United-States       <=50K
# 2              0              0               40   United-States       <=50K
# 3              0              0               40   United-States       <=50K
# 4              0              0               40            Cuba       <=50K

# %%
df.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        'Unnamed: 14'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(" ","")

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Unnamed:14'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace("-",".")

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'Unnamed:14'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# Unnamed:14        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  Unnamed:14      32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
census_ed = df[['education']]

# %%
census_ed.head()
# Out:
#     education
# 0   Bachelors
# 1   Bachelors
# 2     HS-grad
# 3        11th
# 4   Bachelors

# %%
census_seq = df.iloc[:,0:8]

# %%
census_seq.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship
# 0        Never-married        Adm-clerical   Not-in-family
# 1   Married-civ-spouse     Exec-managerial         Husband
# 2             Divorced   Handlers-cleaners   Not-in-family
# 3   Married-civ-spouse   Handlers-cleaners         Husband
# 4   Married-civ-spouse      Prof-specialty            Wife

# %%
census_col = df.iloc[:,[0,5,6]]

# %%
census_col.head()
# Out:
#    age       marital.status          occupation
# 0   39        Never-married        Adm-clerical
# 1   50   Married-civ-spouse     Exec-managerial
# 2   38             Divorced   Handlers-cleaners
# 3   53   Married-civ-spouse   Handlers-cleaners
# 4   28   Married-civ-spouse      Prof-specialty

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
male_gov = df[(df.workclass == ' State-gov') & (df.sex == ' Male')]
len(male_gov)
# Out:
# 809

# %%
census=df[(df['age']==39)]

# %%
census.head()
# Out:
#      age     workclass  fnlwgt      education  education.num  \
# 0     39     State-gov   77516      Bachelors             13
# 28    39       Private  367260        HS-grad              9
# 129   39       Private  365739   Some-college             10
# 166   39   Federal-gov  235485     Assoc-acdm             12
# 297   39             ?  157443        Masters             14
#
#           marital.status        occupation    relationship  \
# 0          Never-married      Adm-clerical   Not-in-family
# 28              Divorced   Exec-managerial   Not-in-family
# 129             Divorced      Craft-repair   Not-in-family
# 166        Never-married   Exec-managerial   Not-in-family
# 297   Married-civ-spouse                 ?            Wife
#
#                     race      sex  capital.gain  capital.loss  hours.per.week  \
# 0                  White     Male          2174             0              40
# 28                 White     Male             0             0              80
# 129                White     Male             0             0              40
# 166                White     Male             0             0              42
# 297   Asian-Pac-Islander   Female          3464             0              40
#
#      native.country Unnamed:14
# 0     United-States      <=50K
# 28    United-States      <=50K
# 129   United-States      <=50K
# 166   United-States      <=50K
# 297               ?      <=50K

# %%
census_us=census[(census['education']=='Bachelors') | (census['native.country']==' United-States')]
census_us.head()
# Out:
#      age          workclass  fnlwgt      education  education.num  \
# 0     39          State-gov   77516      Bachelors             13
# 28    39            Private  367260        HS-grad              9
# 129   39            Private  365739   Some-college             10
# 166   39        Federal-gov  235485     Assoc-acdm             12
# 320   39   Self-emp-not-inc  174308        HS-grad              9
#
#           marital.status        occupation    relationship    race    sex  \
# 0          Never-married      Adm-clerical   Not-in-family   White   Male
# 28              Divorced   Exec-managerial   Not-in-family   White   Male
# 129             Divorced      Craft-repair   Not-in-family   White   Male
# 166        Never-married   Exec-managerial   Not-in-family   White   Male
# 320   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#      capital.gain  capital.loss  hours.per.week  native.country Unnamed:14
# 0            2174             0              40   United-States      <=50K
# 28              0             0              80   United-States      <=50K
# 129             0             0              40   United-States      <=50K
# 166             0             0              42   United-States      <=50K
# 320             0             0              40   United-States      <=50K

# %%
#sample() helps us to get random rows 
# to select 200 random rows

census_200=df.sample(200)
census_200
# Out:
#        age      workclass  fnlwgt      education  education.num  \
# 506     19        Private  249609   Some-college             10
# 2379    42        Private   83411   Some-college             10
# 11214   20        Private  194891        HS-grad              9
# 21180   38        Private  186145   Some-college             10
# 11507   43        Private  117627   Some-college             10
# ...    ...            ...     ...            ...            ...
# 29798   32              ?  119522      Bachelors             13
# 20626   27      State-gov  142621      Bachelors             13
# 25432   48      Local-gov  148549      Bachelors             13
# 20019   61        Private  101500      Assoc-voc             11
# 3760    37   Self-emp-inc  291518      Bachelors             13
#
#             marital.status        occupation    relationship    race      sex  \
# 506          Never-married   Protective-serv       Own-child   White     Male
# 2379              Divorced   Exec-managerial   Not-in-family   White     Male
# 11214        Never-married      Adm-clerical   Not-in-family   White   Female
# 21180   Married-civ-spouse             Sales            Wife   White   Female
# 11507             Divorced   Exec-managerial   Not-in-family   Black   Female
# ...                    ...               ...             ...     ...      ...
# 29798             Divorced                 ?   Not-in-family   White     Male
# 20626        Never-married    Prof-specialty   Not-in-family   White   Female
# 25432   Married-civ-spouse    Prof-specialty         Husband   White     Male
# 20019   Married-civ-spouse      Adm-clerical         Husband   White     Male
# 3760    Married-civ-spouse      Craft-repair         Husband   White     Male
#
#        capital.gain  capital.loss  hours.per.week  native.country Unnamed:14
# 506               0             0               8   United-States      <=50K
# 2379              0          1408              40   United-States      <=50K
# 11214             0             0              40   United-States      <=50K
# 21180             0             0              40   United-States       >50K
# 11507             0             0              40   United-States      <=50K
# ...             ...           ...             ...             ...        ...
# 29798             0             0              50   United-States      <=50K
# 20626          4101             0              40   United-States      <=50K
# 25432             0             0              40   United-States      <=50K
# 20019             0             0              40   United-States      <=50K
# 3760          15024             0              55   United-States       >50K
#
# [200 rows x 15 columns]

# %%
df.groupby(['workclass'])['capital.gain'].mean()
# Out:
# workclass
#  ?                    606.795752
#  Federal-gov          833.232292
#  Local-gov            880.202580
#  Never-worked           0.000000
#  Private              889.217792
#  Self-emp-inc        4875.693548
#  Self-emp-not-inc    1886.061787
#  State-gov            701.699538
#  Without-pay          487.857143
# Name: capital.gain, dtype: float64

# %%
income = df['Unnamed:14']
df['income'] = income

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education.num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital.status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital.gain  capital.loss  hours.per.week  native.country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#       Unnamed:14  income
# 0          <=50K   <=50K
# 1          <=50K   <=50K
# 2          <=50K   <=50K
# 3          <=50K   <=50K
# 4          <=50K   <=50K
# ...          ...     ...
# 32556      <=50K   <=50K
# 32557       >50K    >50K
# 32558      <=50K   <=50K
# 32559      <=50K   <=50K
# 32560       >50K    >50K
#
# [32561 rows x 16 columns]

# %%
df['income'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
df.drop(columns = 'Unnamed:14',inplace=True)

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education.num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital.status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital.gain  capital.loss  hours.per.week  native.country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
df['marital.status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital.status, dtype: int64

# %%
total = len(df['marital.status'])
married = 14976+418+23
percent_married = (married/total)*100

# %%
percent_married
# Out:
# 47.34805442093302

# %%
df['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
hs50K = len(df[(df['education']==' HS-grad')&(df['income']==' >50K')])
hs_total = 10501

# %%
percent_hsgrade_50K = (hs50K/hs_total)*100

# %%
percent_hsgrade_50K
# Out:
# 15.950861822683555

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lo=LogisticRegression()

# %%
df['occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
x = df['occupation']
x = pd.DataFrame(x)
x
# Out:
#                occupation
# 0            Adm-clerical
# 1         Exec-managerial
# 2       Handlers-cleaners
# 3       Handlers-cleaners
# 4          Prof-specialty
# ...                   ...
# 32556        Tech-support
# 32557   Machine-op-inspct
# 32558        Adm-clerical
# 32559        Adm-clerical
# 32560     Exec-managerial
#
# [32561 rows x 1 columns]

# %%
L = LabelEncoder()

# %%
x = L.fit_transform(x)
x = pd.DataFrame(x)

# %%
y =df['income'].replace(" <=50K",0).replace(' >50K',1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.35,random_state=42)

# %%
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7621303851890848

# %% [markdown]
# # DT

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
df.education.value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
df.education = df.education.replace(['Preschool','1st-4th','5th-6th','7th-8th','9th','10th','11th','12th'],'School')

# %%
df.education = df.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'Higher')
df['marital.status']= df['marital.status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
df['marital.status']= df['marital.status'].replace(['Never-married'], 'not-married')
df['marital.status']= df['marital.status'].replace(['Divorced', 'Separated','Widowed','Married-spouse-absent'], 'other')
df.income = df.income.replace('<=50K', 0)
df.income = df.income.replace('>50K', 1)

# %%
df = df.apply(L.fit_transform)

# %%
df
# Out:
#        age  workclass  fnlwgt  education  education.num  marital.status  \
# 0       22          7    2671          9             12               4
# 1       33          6    2926          9             12               2
# 2       21          4   14086         11              8               0
# 3       36          4   15336          1              6               2
# 4       11          4   19355          9             12               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   10          4   16528          7             11               2
# 32557   23          4    8080         11              8               2
# 32558   41          4    7883         11              8               6
# 32559    5          4   12881         11              8               4
# 32560   35          5   17825         11              8               2
#
#        occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0               1             1     4    1            25             0
# 1               4             0     4    1             0             0
# 2               6             1     4    1             0             0
# 3               6             0     2    1             0             0
# 4              10             5     2    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32556          13             5     4    0             0             0
# 32557           7             0     4    1             0             0
# 32558           1             4     4    0             0             0
# 32559           1             3     4    1             0             0
# 32560           4             5     4    0           108             0
#
#        hours.per.week  native.country  income
# 0                  39              39       0
# 1                  12              39       0
# 2                  39              39       0
# 3                  39              39       0
# 4                  39               5       0
# ...               ...             ...     ...
# 32556              37              39       0
# 32557              39              39       1
# 32558              39              39       0
# 32559              19              39       0
# 32560              39              39       1
#
# [32561 rows x 15 columns]

# %%
x= df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.35,random_state=42)

# %%
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8067912608581206

# %% [markdown]
# # RF

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8568044222163728
